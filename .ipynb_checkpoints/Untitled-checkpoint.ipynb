# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
df.head(10)
# Out:
#    season  week_num day_of_week gametime_local home_team        away_team  \
# 0    2011         1      Sunday     1:15:00 PM   Arizona         Carolina
# 1    2011         4      Sunday     1:05:00 PM   Arizona  New York Giants
# 2    2011         7      Sunday     1:05:00 PM   Arizona       Pittsburgh
# 3    2011         9      Sunday     2:15:00 PM   Arizona        St. Louis
# 4    2011        13      Sunday     2:15:00 PM   Arizona           Dallas
# 5    2011        14      Sunday     2:05:00 PM   Arizona    San Francisco
# 6    2011        15      Sunday     2:15:00 PM   Arizona        Cleveland
# 7    2011        17      Sunday     2:15:00 PM   Arizona          Seattle
# 8    2012         1      Sunday     1:25:00 PM   Arizona          Seattle
# 9    2012         3      Sunday     1:05:00 PM   Arizona     Philadelphia
#
#    home_score  away_score OT_flag  arrests division_game
# 0          28          21     NaN      5.0             n
# 1          27          31     NaN      6.0             n
# 2          20          32     NaN      9.0             n
# 3          19          13      OT      6.0             y
# 4          19          13      OT      3.0             n
# 5          21          19     NaN      4.0             y
# 6          20          17      OT      1.0             n
# 7          23          20      OT      4.0             y
# 8          20          16     NaN      0.0             y
# 9          27           6     NaN     12.0             n

# %%
df.describe()
# Out:
#             season     week_num   home_score   away_score     arrests
# count  1006.000000  1006.000000  1006.000000  1006.000000  966.000000
# mean   2013.000000     9.116302    23.934394    21.115308    6.566253
# std       1.406453     5.008986    10.442626     9.734006    9.512101
# min    2011.000000     1.000000     0.000000     0.000000    0.000000
# 25%    2012.000000     5.000000    17.000000    14.000000    1.000000
# 50%    2013.000000     9.000000    23.000000    20.000000    3.000000
# 75%    2014.000000    14.000000    30.000000    27.000000    8.000000
# max    2015.000000    17.000000    59.000000    56.000000   69.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006 entries, 0 to 1005
# Data columns (total 11 columns):
# season            1006 non-null int64
# week_num          1006 non-null int64
# day_of_week       1006 non-null object
# gametime_local    1006 non-null object
# home_team         1006 non-null object
# away_team         1006 non-null object
# home_score        1006 non-null int64
# away_score        1006 non-null int64
# OT_flag           59 non-null object
# arrests           966 non-null float64
# division_game     1006 non-null object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 86.5+ KB

# %% [markdown]
# ## which home team has the most arrests?

# %%
# add in home team win flag
df['home_team_win'] = df['home_score'] > df['away_score']
df.head(3)
# Out:
#    season  week_num day_of_week gametime_local home_team        away_team  \
# 0    2011         1      Sunday     1:15:00 PM   Arizona         Carolina
# 1    2011         4      Sunday     1:05:00 PM   Arizona  New York Giants
# 2    2011         7      Sunday     1:05:00 PM   Arizona       Pittsburgh
#
#    home_score  away_score OT_flag  arrests division_game  home_team_win
# 0          28          21     NaN      5.0             n           True
# 1          27          31     NaN      6.0             n          False
# 2          20          32     NaN      9.0             n          False

# %%
team_arrests = df[['home_team', 'home_team_win', 'arrests']].groupby(['home_team', 'home_team_win']).sum()
team_arrests
# Out:
#                                arrests
# home_team       home_team_win
# Arizona         False             55.0
#                 True             111.0
# Baltimore       False             18.0
#                 True              28.0
# Carolina        False             18.0
#                 True              37.0
# Chicago         False             13.0
#                 True              13.0
# Cincinnati      False             27.0
#                 True              30.0
# Dallas          False             84.0
#                 True              85.0
# Denver          False             13.0
#                 True              92.0
# Detroit         False              NaN
#                 True               NaN
# Green Bay       False             68.0
#                 True             220.0
# Houston         False             17.0
#                 True              23.0
# Indianapolis    False             43.0
#                 True              48.0
# Jacksonville    False             44.0
#                 True              20.0
# Kansas City     False             27.0
#                 True              44.0
# Miami           False             41.0
#                 True              33.0
# New England     False             23.0
#                 True             165.0
# New York Giants False            518.0
#                 True             381.0
# New York Jets   False            422.0
#                 True             436.0
# Oakland         False            425.0
#                 True             233.0
# Philadelphia    False             65.0
#                 True              61.0
# Pittsburgh      False            256.0
#                 True             414.0
# San Diego       False            481.0
#                 True             502.0
# San Francisco   False            189.0
#                 True             265.0
# Seattle         False              4.0
#                 True              28.0
# Tampa Bay       False             22.0
#                 True              11.0
# Tennessee       False             64.0
#                 True              19.0
# Washington      False             57.0
#                 True              50.0

# %% [markdown]
# ## Home team loses & number of arrests

# %%
sns.factorplot(x="home_team", y="arrests", hue="home_team_win", data=df,
                   size=25, kind="bar", palette="muted", legend_out=True).set_xticklabels(rotation=30)

# %% [markdown]
# ## Home team V's away team arrests:

# %%
TODO:
    arrests as % of stadium capacity

# %%
sidf[['home_team_win','arrests']].groupby(['home_team_win']).sum()
# Out:
#                arrests
# home_team_win
# False           2994.0
# True            3349.0

# %%
df[['home_team_win','arrests']].groupby(['home_team_win']).sum().plot(kind='pie', y='arrests')

# %%
sizes = df[['home_team_win','arrests']].groupby(['home_team_win']).sum()
explode = (0, 0.05)
labels = ('Home team loses', 'home team wins')
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
plt.title('Arrests Percentages if home team wins/loses', size=20)
# Out:
# Text(0.5,1,'Arrests Percentages if home team wins/loses')

# %%
## Obtain additional data on NFL stadiums

# %%
pd.read_html('http://www.stadiumsofprofootball.com/comparisons/')
# Out:
# [                             Name               Team(s)  Capacity     Opened  \
#  0                   Lambeau Field     Green Bay Packers     80735  9/29/1957
#  1                Oakland Coliseum       Oakland Raiders     53250  9/18/1966
#  2                Qualcomm Stadium    San Diego Chargers     71500  8/20/1967
#  3               Arrowhead Stadium    Kansas City Chiefs     76416  8/12/1972
#  4                   New Era Field         Buffalo Bills     73967  8/17/1973
#  5                       Superdome    New Orleans Saints     76468  9/28/1975
#  6               Hard Rock Stadium        Miami Dolphins     65326  8/16/1987
#  7                    Georgia Dome       Atlanta Falcons     71250   9/6/1992
#  8                  EverBank Field  Jacksonville Jaguars     67264  8/18/1995
#  9            Los Angeles Coliseum      Los Angeles Rams     93605  9/18/2016
#  10        Bank of America Stadium     Carolina Panthers     73778  9/14/1996
#  11                    FedEx Field   Washington Redskins     79000  9/14/1997
#  12               M&T Bank Stadium      Baltimore Ravens     71008   9/6/1998
#  13          Raymond James Stadium  Tampa Bay Buccaneers     65890  9/20/1998
#  14            FirstEnergy Stadium      Cleveland Browns     68000  9/12/1999
#  15                 Nissan Stadium      Tennessee Titans     69143  9/12/1999
#  16             Paul Brown Stadium    Cincinnati Bengals     65515  9/10/2000
#  17         Sports Authority Field        Denver Broncos     76125  9/10/2001
#  18                    Heinz Field   Pittsburgh Steelers     65500  10/7/2001
#  19                    NRG Stadium        Houston Texans     71500   9/8/2002
#  20               Gillette Stadium  New England Patriots     68756   9/9/2002
#  21              CenturyLink Field      Seattle Seahawks     67000  9/15/2002
#  22                     Ford Field         Detroit Lions     65000  9/22/2002
#  23        Lincoln Financial Field   Philadelphia Eagles     69176   9/8/2003
#  24                  Soldier Field         Chicago Bears     61500  9/29/2003
#  25  University of Phoenix Stadium     Arizona Cardinals     63400  9/10/2006
#  26              Lucas Oil Stadium    Indianapolis Colts     63000   9/7/2008
#  27                   AT&T Stadium        Dallas Cowboys     80000  9/20/2009
#  28                MetLife Stadium  New York Giants/Jets     82500  9/12/2010
#  29                 Levi's Stadium   San Francisco 49ers     68500  9/14/2014
#  30                US Bank Stadium     Minnesota Vikings     66200  9/18/2016
#
#           Turf           Cost
#  0       Grass       $960,000
#  1       Grass  $25.5 Million
#  2       Grass    $27 Million
#  3       Grass    $43 Million
#  4   FieldTurf    $22 Million
#  5   FieldTurf   $134 Million
#  6       Grass   $115 Million
#  7   FieldTurf   $214 Million
#  8       Grass   $134 Million
#  9       Grass       $954,872
#  10      Grass   $242 Million
#  11      Grass   $250 Million
#  12  Fieldturf   $220 Million
#  13      Grass   $194 Million
#  14      Grass   $290 Million
#  15      Grass   $290 Million
#  16  Fieldturf   $450 Million
#  17      Grass   $364 Million
#  18      Grass   $281 Million
#  19      Grass   $449 Million
#  20  Fieldturf   $325 Million
#  21  FieldTurf   $360 Million
#  22  FieldTurf   $430 Million
#  23      Grass   $518 Million
#  24      Grass   $600 Million
#  25      Grass   $455 Million
#  26  Fieldturf   $720 Million
#  27  FieldTurf   $1.3 Billion
#  28  FieldTurf   $1.6 Billion
#  29      Grass   $1.3 Billion
#  30  FieldTurg   $1.1 Billion  ]

# %%
team_data = pd.read_html('https://en.wikipedia.org/wiki/National_Football_League')
# http://nflarrest.com

# %%
pd.read_json("http://nflarrest.com/api/v1/team?start_date=20170101")
# Out:
#    Team Team_Conference Team_Conference_Division      Team_city  Team_logo_id  \
# 0    GB             NFC                NFC North      Green Bay            12
# 1   SEA             NFC                 NFC West        Seattle            28
# 2   NYG             NFC                 NFC East       New York            21
# 3    KC             AFC                 AFC West    Kansas City            16
# 4    LA             NFC                 NFC West    Los Angeles            29
# 5    SF             NFC                 NFC West  San Francisco            27
# 6   NYJ             AFC                 AFC East       New York            22
# 7   DEN             AFC                 AFC West         Denver            10
# 8   DAL             NFC                 NFC East         Dallas             9
# 9   BAL             AFC                AFC North      Baltimore             3
# 10  CIN             AFC                AFC North     Cincinnati             7
# 11  CLE             AFC                AFC North      Cleveland             8
# 12  HOU             AFC                AFC South        Houston            13
# 13   NO             NFC                NFC South    New Orleans            20
# 14  CAR             NFC                NFC South      Charlotte             5
# 15  ARI             NFC                 NFC West        Phoenix             1
# 16  CHI             NFC                NFC North        Chicago             6
# 17  IND             AFC                AFC South   Indianapolis            14
# 18   TB             NFC                NFC South      Tampa Bay            30
# 19  OAK             AFC                 AFC West        Oakland            23
# 20  BUF             AFC                 AFC East        Buffalo             4
# 21  WAS             NFC                 NFC East  Washington DC            32
# 22  LAC             AFC                 AFC West    Los Angeles            26
# 23  MIA             AFC                 AFC East          Miami            17
# 24  JAC             AFC                AFC South   Jacksonville            15
# 25  PIT             AFC                AFC North     Pittsburgh            25
#
#         Team_name   Team_preffered_name  arrest_count
# 0         Packers     Green Bay Packers             4
# 1        Seahawks      Seattle Seahawks             4
# 2       NY Giants       New York Giants             3
# 3          Chiefs    Kansas City Chiefs             3
# 4            Rams      Los Angeles Rams             3
# 5           49ers   San Francisco 49ers             3
# 6            Jets         New York Jets             3
# 7         Broncos        Denver Broncos             2
# 8         Cowboys        Dallas Cowboys             2
# 9          Ravens      Baltimore Ravens             2
# 10        Bengals    Cincinnati Bengals             1
# 11         Browns      Cleveland Browns             1
# 12         Texans        Houston Texans             1
# 13         Saints    New Orleans Saints             1
# 14       Panthers     Carolina Panthers             1
# 15      Cardinals     Arizona Cardinals             1
# 16          Bears         Chicago Bears             1
# 17          Colts    Indianapolis Colts             1
# 18     Buccaneers  Tampa Bay Buccaneers             1
# 19        Raiders       Oakland Raiders             1
# 20  Buffalo Bills         Buffalo Bills             1
# 21       Redskins   Washington Redskins             1
# 22       Chargers  Los Angeles Chargers             1
# 23       Dolphins        Miami Dolphins             1
# 24        Jaguars  Jacksonville Jaguars             1
# 25       Steelers   Pittsburgh Steelers             1

# %%
TODO:
    summerize fan data by year, home team, arrest #'s
    get player data for same & merge, compare arrests between teams & players
